# %% [markdown]
# # Глубинное обучение для текстовых данных, ФКН ВШЭ
# ## Домашнее задание 4: Direct Preference Optimization
#
# __Мягкий дедлайн 16.11.25 23:59__ \
# __Жесткий дедлайн 19.11.25 23:59__
#
# ### О задании
#
# В этом задании вам предстоит обучить большую LLM для ответов на вопросы с помощью DPO, а также реализовать LoRA для эффективного обучения.
#
# ### Оценивание и штрафы
#
# Максимально допустимая оценка за работу — __11 баллов__.
#
# Оценка за это домашнее задание будет формироваться из оценки за __задания__ и за __отчет__, в котором от вас требуется написать о проделанной работе. За отчет можно получить до 2-х баллов, однако в случае отсутствия отчета баллы за соответствующие задания не будут ставиться. Мы настаиваем на том, чтобы вы оформили весь код в виде полноценного проекта. Этот ноутбук нужно рассматривать скорее как файл с условием, чем как место для написания массивного кода. За сдачу больших ноутбуков с кодом оценка будет снижена. Ответы на все вопросы в заданиях можно (нужно) писать в отчете.
#
# Задание выполняется самостоятельно. «Похожие» решения считаются плагиатом и все задействованные студенты (в том числе те, у кого списали) не могут получить за него больше 0 баллов. Весь код должен быть написан самостоятельно. Чужим кодом для пользоваться запрещается даже с указанием ссылки на источник. В разумных рамках, конечно. Взять пару очевидных строчек кода для реализации какого-то небольшого функционала можно.
#
# ### План решения
#
# <img src="https://miro.medium.com/v2/resize:fit:1400/1*lK6iJMz5CGh2fo7TsDn15A.png" alt="drawing" width="700"/>
#
# Обучение следованию инструкциям с помощью DPO разбивается на два этапа:
# 1. __Supervised Fine-tuning (SFT)__ – обучение базовой модели ответам на запросы в нужном формате.
# 2. __Direct Preference Optimization (DPO)__ – обучение SFT модели приоритизации "хороших" ответов.
#
# Мы не хотим обучать модели целиком по двум причинам: 1) используемые модели очень большие; 2) нам требуется лишь выравнить модель с нашими предпочтениями, не внося в нее новых знаний, что не требует серьезного обучения. Поэтому мы будем использовать PEFT, а именно LoRA для обучения.
#
# Таким образом, вам надо будет:
# 1. Реализовать и протестировать LoRA
# 2. Разобраться с данными и привести их к нужному формату
# 3. Обучить SFT модель
# 4. Обучить DPO модель
# 5. Порадоваться, что вы молодцы и со всем справились
# 6. (Опционально) сделать веб-интерфейс для вашей модели, переиспользуя код из первой домашки (мы можем выдать бонусы, если получится классно).

# %% [markdown]
# ### О датасете
#
# Мы будем работать с датасетом [Anthropic Helpful-Harmless](https://huggingface.co/datasets/Anthropic/hh-rlhf) для RLHF. В нем содержится 160к примеров ответов на вопросы с историей.

# %% [markdown]
# ### Low-Rank Adaptation (LoRA)
#
# <img src="https://heidloff.net/assets/img/2023/08/lora.png" alt="drawing" width="600"/>
#
# __Задание 1 (3 балла).__ Реализуйте самостоятельно модуль LoRA для эффективного обучения LLM по схеме, описанной в [статье](https://arxiv.org/pdf/2106.09685). Встройте его в свою любимую LLM и убедитесь, что ошибка убывает при обучении параметров LoRA на безусловную генерацию. Для этого возьмите любые данные на свой выбор. Замерьте насколько уменьшилось число обучаемых параметров, как изменилась скорость во время forward и backward процессов и как изменились затраты по памяти. Сделайте выводы и напишите о них в отчете.

# %%
from utils import get_tokenizer, get_dataloaders, count_trinable_params
from lora import get_base_model, get_lora_model, train_model_exp, eval_model_exp
from sft import get_sft_dataloaders, train_model_sft, eval_model_sft

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import torch
import torch.nn as nn
from transformers import GPT2Config, GPT2Model, GPT2Tokenizer, RobertaPreTrainedModel, AutoModelForSequenceClassification
from datasets import load_dataset
from torch.utils.data import DataLoader
import time
import psutil
import os
import warnings

warnings.filterwarnings("ignore")

# %%
tokenizer = get_tokenizer()
train_loader, val_loader = get_dataloaders(tokenizer)
# Out:
# Using the latest cached version of the dataset since Anthropic/hh-rlhf couldn't be found on the Hugging Face Hub
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 2
#       1 tokenizer = get_tokenizer()
# ----> 2 train_loader, val_loader = get_dataloaders(tokenizer)
#
# File ~/HSE/HSE-DL_for_NLP/hw4/utils.py:9, in get_dataloaders(tokenizer, dataset_name, train_len, val_len)
#       6 def get_tokenizer():
#       7     os.environ['TOKENIZERS_PARALLELISM'] = 'false'
# ----> 9     tokenizer = AutoTokenizer.from_pretrained("EleutherAI/pythia-1.4b")
#      10     tokenizer.add_special_tokens({'pad_token': '[PAD]'})
#      12     return tokenizer
#
# File ~/Library/Python/3.9/lib/python/site-packages/datasets/load.py:2061, in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, keep_in_memory, save_infos, revision, token, streaming, num_proc, storage_options, trust_remote_code, **config_kwargs)
#    2056 verification_mode = VerificationMode(
#    2057     (verification_mode or VerificationMode.BASIC_CHECKS) if not save_infos else VerificationMode.ALL_CHECKS
#    2058 )
#    2060 # Create a dataset builder
# -> 2061 builder_instance = load_dataset_builder(
#    2062     path=path,
#    2063     name=name,
#    2064     data_dir=data_dir,
#    2065     data_files=data_files,
#    2066     cache_dir=cache_dir,
#    2067     features=features,
#    2068     download_config=download_config,
#    2069     download_mode=download_mode,
#    2070     revision=revision,
#    2071     token=token,
#    2072     storage_options=storage_options,
#    2073     trust_remote_code=trust_remote_code,
#    2074     _require_default_config_name=name is None,
#    2075     **config_kwargs,
#    2076 )
#    2078 # Return iterable dataset in case of streaming
#    2079 if streaming:
#
# File ~/Library/Python/3.9/lib/python/site-packages/datasets/load.py:1818, in load_dataset_builder(path, name, data_dir, data_files, cache_dir, features, download_config, download_mode, revision, token, storage_options, trust_remote_code, _require_default_config_name, **config_kwargs)
#    1816 builder_cls = get_dataset_builder_class(dataset_module, dataset_name=dataset_name)
#    1817 # Instantiate the dataset builder
# -> 1818 builder_instance: DatasetBuilder = builder_cls(
#    1819     cache_dir=cache_dir,
#    1820     dataset_name=dataset_name,
#    1821     config_name=config_name,
#    1822     data_dir=data_dir,
#    1823     data_files=data_files,
#    1824     hash=dataset_module.hash,
#    1825     info=info,
#    1826     features=features,
#    1827     token=token,
#    1828     storage_options=storage_options,
#    1829     **builder_kwargs,
#    1830     **config_kwargs,
#    1831 )
#    1832 builder_instance._use_legacy_cache_dir_if_possible(dataset_module)
#    1834 return builder_instance
#
# File ~/Library/Python/3.9/lib/python/site-packages/datasets/packaged_modules/cache/cache.py:124, in Cache.__init__(self, cache_dir, dataset_name, config_name, version, hash, base_path, info, features, token, repo_id, data_files, data_dir, storage_options, writer_batch_size, **config_kwargs)
#     122     config_kwargs["data_dir"] = data_dir
#     123 if hash == "auto" and version == "auto":
# --> 124     config_name, version, hash = _find_hash_in_cache(
#     125         dataset_name=repo_id or dataset_name,
#     126         config_name=config_name,
#     127         cache_dir=cache_dir,
#     128         config_kwargs=config_kwargs,
#     129         custom_features=features,
#     130     )
#     131 elif hash == "auto" or version == "auto":
#     132     raise NotImplementedError("Pass both hash='auto' and version='auto' instead")
#
# File ~/Library/Python/3.9/lib/python/site-packages/datasets/packaged_modules/cache/cache.py:64, in _find_hash_in_cache(dataset_name, config_name, cache_dir, config_kwargs, custom_features)
#      56     cached_directory_paths = [
#      57         cached_directory_path
#      58         for cached_directory_path in glob.glob(os.path.join(cached_datasets_directory_path_root, "*", "*", "*"))
#      59         if os.path.isdir(cached_directory_path)
#      60     ]
#      61     available_configs = sorted(
#      62         {Path(cached_directory_path).parts[-3] for cached_directory_path in cached_directory_paths}
#      63     )
# ---> 64     raise ValueError(
#      65         f"Couldn't find cache for {dataset_name}"
#      66         + (f" for config '{config_id}'" if config_id else "")
#      67         + (f"\nAvailable configs in the cache: {available_configs}" if available_configs else "")
#      68     )
#      69 # get most recent
#      70 cached_directory_path = Path(sorted(cached_directory_paths, key=_get_modification_time)[-1])
#
# ValueError: Couldn't find cache for Anthropic/hh-rlhf for config 'default-data_dir=harmless-base'
# Available configs in the cache: ['default', 'default-52e03caf22ec705f']

# %%
base_model = get_base_model()
print(f'Обучаемых параметров: {count_trinable_params(base_model)}')

lora_model = get_lora_model(lora_rank=4)
print(f'Обучаемых параметров с LoRA: {count_trinable_params(lora_model)}')
# Out:
# Обучаемых параметров: 1414647808
# Обучаемых параметров с LoRA: 3355136

# %%
# lora_model.eval()
# base_model.eval()
train_model_exp(lora_model, tokenizer, train_loader, val_loader, max_length=32)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 3
#       1 # lora_model.eval()
#       2 # base_model.eval()
# ----> 3 train_model_exp(lora_model, tokenizer, train_loader, val_loader, max_length=32)
#
# Cell In[2], line 123, in train_model_exp(model, tokenizer, train_loader, val_loader, epochs, max_length)
#     120 opt = torch.optim.Adam(model.parameters(), lr=0.01)
#     121 model.to(device)
# --> 123 torch.cuda.reset_max_memory_allocated()
#     124 torch.cuda.reset_peak_memory_stats()
#     125 torch.cuda.synchronize()
#
# File ~/Library/Python/3.9/lib/python/site-packages/torch/cuda/memory.py:496, in reset_max_memory_allocated(device)
#     474 r"""Reset the starting point in tracking maximum GPU memory occupied by tensors for a given device.
#     475
#     476 See :func:`~torch.cuda.max_memory_allocated` for details.
#    (...)
#     489     management.
#     490 """
#     491 warnings.warn(
#     492     "torch.cuda.reset_max_memory_allocated now calls torch.cuda.reset_peak_memory_stats, "
#     493     "which resets /all/ peak memory stats.",
#     494     FutureWarning,
#     495 )
# --> 496 return reset_peak_memory_stats(device=device)
#
# File ~/Library/Python/3.9/lib/python/site-packages/torch/cuda/memory.py:375, in reset_peak_memory_stats(device)
#     360 def reset_peak_memory_stats(device: "Device" = None) -> None:
#     361     r"""Reset the "peak" stats tracked by the CUDA memory allocator.
#     362
#     363     See :func:`~torch.cuda.memory_stats` for details. Peak stats correspond to the
#    (...)
#     373         management.
#     374     """
# --> 375     device = _get_device_index(device, optional=True)
#     376     return torch._C._cuda_resetPeakMemoryStats(device)
#
# File ~/Library/Python/3.9/lib/python/site-packages/torch/cuda/_utils.py:363, in _get_device_index(device, optional, allow_cpu)
#     361     if isinstance(device, torch.cuda.device):
#     362         return device.idx
# --> 363 return _torch_get_device_index(device, optional, allow_cpu)
#
# File ~/Library/Python/3.9/lib/python/site-packages/torch/_utils.py:870, in _get_device_index(device, optional, allow_cpu)
#     868         device_idx = get_current_device_index()
#     869     else:
# --> 870         device_idx = _get_current_device_index()
#     871 else:
#     872     raise ValueError(
#     873         f"Expected a torch.device with a specified index or an integer, but got:{device}"
#     874     )
#
# File ~/Library/Python/3.9/lib/python/site-packages/torch/_utils.py:807, in _get_current_device_index()
#     805 def _get_current_device_index():
#     806     # current device index
# --> 807     return _get_device_attr(lambda m: m.current_device())
#
# File ~/Library/Python/3.9/lib/python/site-packages/torch/_utils.py:794, in _get_device_attr(get_member)
#     792     return get_member(torch.cuda)
#     793 if device_type and device_type.lower() == "mps":
# --> 794     return get_member(torch.mps)
#     795 if device_type and device_type.lower() == "xpu":
#     796     return get_member(torch.xpu)  # type: ignore[attr-defined]
#
# File ~/Library/Python/3.9/lib/python/site-packages/torch/_utils.py:807, in _get_current_device_index.<locals>.<lambda>(m)
#     805 def _get_current_device_index():
#     806     # current device index
# --> 807     return _get_device_attr(lambda m: m.current_device())
#
# AttributeError: module 'torch.mps' has no attribute 'current_device'

# %%
import time
def train_model_exp(model, texts, num_steps=100):
    # time and memory
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    opt = torch.optim.Adam(model.parameters(), lr=0.01)
    model.to(device)
    torch.cuda.reset_max_memory_allocated()
    torch.cuda.reset_peak_memory_stats()
    torch.cuda.synchronize()
    start_time = time.perf_counter()
    for i in range(num_steps):
        inputs = tokenizer(texts, max_length=1024, return_tensors='pt', truncation=True).to(device)
        outputs = model(**inputs)
        next_word_logits = outputs.logits[:, : -1, :]
        true_next_tokens = inputs['input_ids'][:, 1:]
        loss = F.cross_entropy(next_word_logits.flatten(0, 1), true_next_tokens.flatten(0, 1))
        loss.backward()
        opt.step()
        opt.zero_grad()
        if i%10==0:
            print("Loss:", loss.item())
    torch.cuda.synchronize()
    time_elapsed = time.perf_counter() - start_time
    memory = torch.cuda.max_memory_allocated()
    return time_elapsed, memory

# %%
inputs = tokenizer(batch['chosen'], max_length=4, truncation=True, padding='max_length', return_tensors='pt')
# print(inputs)
lora_model(**inputs)

# %%
input_ids[attn_masks].max(), input_ids.min()

# %%
res = base_model(torch.tensor(tokenized[0][0], dtype=int))
len(res)

# %%
len(batch['chosen'])

# %%
res[0].shape

# %% [markdown]
# ### Supervised Fine-tuning
#
# __Задание 2 (3 балла).__ Разбейте все примеры с "хорошими" ответами на запросы (все что идет до последнего "Assistant:") и ответы (все, начиная с последнего "Assistant:"). Дообучите модель [`pythia-1.4b`](https://huggingface.co/EleutherAI/pythia-1.4b) генерировать правильные ответы с помощью вашей LoRA. Одной эпохи вполне должно хватить для сходимости. Проверьте на нескольких случайных тестовых примерах, что модель ведет себя так, как надо.

# %%
sft_train_loader, sft_val_loader = prepare_sft_dataloaders(train_loader, val_loader)

# %%
# your code here

# %% [markdown]
# ### Direct Preference Optimization

# %% [markdown]
# __Задание 3 (3 балла).__ Реализуйте DPO согласно [статье](https://arxiv.org/pdf/2305.18290) и дообучите SFT модель с предыдущего шага. Одной эпохи так же должно хватить, но можно обучать и дольше. Убедитесь, что модель начинает отдавать предпочтение хорошим ответам. Проведите анализ. Стали ли ответы лучше, чем у SFT модели? Всегда ли модель отвечает хорошо или иногда плохо? Насколько легко модель ломается при изменении промптов?
